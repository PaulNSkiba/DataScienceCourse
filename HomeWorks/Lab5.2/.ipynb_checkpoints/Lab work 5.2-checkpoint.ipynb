# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 5: Data analysis with NumPy and Pandas

# %% [markdown]
# ## Lab work 5.2

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із бібліотекою Pandas в Python.

# %% [markdown]
# ### Завдання:

# %%
import pandas as pd

# %% [markdown]
# Вивести версію та конфігурацію бібліотеки:

# %%
import pandas as pd
print (pd.__version__)
print(pd.describe_option())
# Out:
# 1.2.4
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# ...

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print(df)
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# Скільки рядків і стовпців в наборі даних:

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Rows:', df.shape[0])
print('Columns:', len(df.columns))
print('Columns:', df.shape[1])
# Out:
# Rows: 10000
# Columns: 14
# Columns: 14

# %% [markdown]
# Перевірити, чи в наборі даних містяться порожні значення:

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Contains null:', df.isnull().values.any())
print('Contains null:', df.isnull().any().any())
# Out:
# Contains null: False
# Contains null: False

# %% [markdown]
# Яка середня ціна закупки (Purchase Price):

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print(df['Purchase Price'].mean())
# Out:
# 50.34730200000025

# %% [markdown]
# Скільки людей користуються англійською мовою "en" на веб-сайті:

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('English speaking users:', len(df[df['Language']=='en']))
# Out:
# English speaking users: 1098

# %% [markdown]
# Скільки людей має посаду «Lawyer»?

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Lawyer position users:', len(df[df['Job'].str.contains('Lawyer', case = False)]))
# Out:
# Lawyer position users: 30

# %% [markdown]
# Скільки людей зробило покупку вранці та скільки людей зробило покупку після обіду?

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Buying time:', df.groupby('AM or PM').size())
print('-----')
print('Buying time:', df.groupby('AM or PM')['AM or PM'].count())
# Out:
# Buying time: AM or PM
# AM    4932
# PM    5068
# dtype: int64
# -----
# Buying time: AM or PM
# AM    4932
# PM    5068
# Name: AM or PM, dtype: int64

# %% [markdown]
# Які 5 найпоширеніших назв вакансій?

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Top 5 Jobs:')
print(df.groupby('Job')['Job'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(5).to_string(index=False))
# Out:
# Top 5 Jobs:
#                               Job  count
#     Interior and spatial designer     31
#                            Lawyer     30
#                 Social researcher     28
#               Designer, jewellery     27
# Research officer, political party     27

# %% [markdown]
# Хтось здійснив покупку, яка надійшла від Lot: "90 Wt", та якою була ціна придбання для цієї транзакції?

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Purchase price:', df[df['Lot'].str.contains("90 Wt", case = False)]['Purchase Price'].to_string(index=False))
# Out:
# Purchase price: 75.1

# %% [markdown]
# Яка електронна адреса особи з таким номером кредитної картки: 4926535242672853 ?

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Email of [4926535242672853]:', df[df['Credit Card']==4926535242672853]['Email'].to_string(index=False))
# Out:
# Email of [4926535242672853]: bondellen@williams-garza.com

# %% [markdown]
# Скільки людей використовує American Express  і здійснили покупку на суму понад 100 доларів?

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Buyers with AE and purchase price > 100:', len(df[(df['CC Provider']=="American Express") & (df['Purchase Price']>100)]))
# Out:
# Buyers with AE and purchase price > 100: 0

# %% [markdown]
# Скільки людей мають кредитну картку, термін дії якої закінчується в 2025 році?

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
print('Credit cards expiring in 2025:', len(df[df['CC Exp Date'].str.contains('/25')]))
# Out:
# Credit cards expiring in 2025: 1033

# %% [markdown]
# Які найкращі 5 найпопулярніших постачальників / хостів електронної пошти (наприклад, gmail.com, yahoo.com тощо ...).

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
df['Domen'] = df.Email.apply(lambda x: x.split('@')[1])
print(df.groupby('Domen')['Domen'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(5).to_string(index=False))
# Out:
#        Domen  count
#  hotmail.com   1638
#    yahoo.com   1616
#    gmail.com   1605
#    smith.com     42
# williams.com     37

# %% [markdown]
# Виведіть зведену таблицю по браузерах(Browser Info), посаді(Job), та кількості транзакцій :

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
df['Browser'] = df['Browser Info'].apply(lambda x: x.split('/')[0])
pvt = df.pivot_table(index=['Job'], columns=['Browser'], values='Purchase Price', aggfunc='count')
pvt
# Out:
# Browser                           Mozilla  Opera
# Job
# Academic librarian                   10.0    1.0
# Accommodation manager                11.0    6.0
# Accountant, chartered                14.0    6.0
# Accountant, chartered certified      13.0    5.0
# Accountant, chartered management     10.0    5.0
# ...                                   ...    ...
# Water quality scientist              13.0    5.0
# Web designer                         13.0    7.0
# Wellsite geologist                   22.0    2.0
# Writer                                9.0    1.0
# Youth worker                         15.0    3.0
#
# [623 rows x 2 columns]

# %% [markdown]
# Створіть нову колонку "Actual price", яка утворюється із "Purchase Price" та націнки за принципом:
# - якщо "Purchase Price" > 50, націнка 20%
# - якщо "Purchase Price" > 100, націнка 10%
# - в інших випадках націнка 30%

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
def actualPrice(price):
    if price > 50:
        return price * 1.2
    elif price > 100:
        return price * 1.1
    else:
        return price * 1.3
    
df['Actual price'] = df['Purchase Price'].apply(lambda x: actualPrice(x))
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# Зробіть рангування набору даних по "Language" та "Actual price" в порядку спадання ціни.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rank.html

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
def actualPrice(price):
    if price > 50:
        return price * 1.2
    elif price > 100:
        return price * 1.1
    else:
        return price * 1.3
    
df['Actual price'] = df['Purchase Price'].apply(lambda x: actualPrice(x))
res = df.groupby('Language')['Actual price'].max().reset_index(name='price').sort_values(['price'], ascending=False)
res['Price rank'] = res['price'].rank(ascending=False)
res
# Out:
#   Language    price  Price rank
# 0       de  119.988         1.5
# 1       el  119.988         1.5
# 4       fr  119.904         3.5
# 5       it  119.904         3.5
# 3       es  119.880         5.5
# 6       pt  119.880         5.5
# 2       en  119.832         7.0
# 7       ru  119.700         8.0
# 8       zh  119.532         9.0

# %% [markdown]
# Колонку "Language" (категоріальна змінна) "закодуйте", тобто утворити індикаторні колоник. В наборі не повинна залишитися колонка "Language".
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rank.html

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
    
df = pd.get_dummies(df, columns = ['Language'])
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# Кінцевий набір даних збережіть у файл з розширенням csv.

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
    
df = pd.get_dummies(df, columns = ['Language'])
df.to_csv('Ecommerce Purchases.csv')
